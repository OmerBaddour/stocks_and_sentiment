# %%
import yfinance as yf

# %%
yf.Ticker("MSFT").info
# Out:
# {'zip': '98052-6399',
#  'sector': 'Technology',
#  'fullTimeEmployees': 181000,
# ...

# %%
t = yf.Ticker("iaiouieeou")

# %%
type(t.info), t.info
# Out:
# (dict, {'regularMarketPrice': None, 'preMarketPrice': None, 'logo_url': ''})

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import datetime

# %%
today = datetime.date.today()
start = (today - datetime.timedelta(days=30)).strftime("%Y-%m-%d")
end = today.strftime("%Y-%m-%d")

tcs = yf.download('TCS',start,end)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
tcs
# Out:
#              Open   High    Low  Close  Adj Close   Volume
# Date
# 2021-10-18  10.05  10.35   9.97  10.27      10.27   332400
# 2021-10-19  10.13  10.42  10.13  10.20      10.20   493600
# 2021-10-20  10.12  10.75  10.12  10.50      10.50   577700
# 2021-10-21  10.50  10.92  10.38  10.85      10.85   550900
# 2021-10-22  10.84  10.86  10.52  10.67      10.67   444100
# 2021-10-25  10.66  10.93  10.63  10.90      10.90   302000
# 2021-10-26  10.93  11.00  10.30  10.36      10.36   350000
# 2021-10-27  10.38  10.52  10.04  10.45      10.45   731500
# 2021-10-28  10.49  10.94  10.36  10.90      10.90   430200
# 2021-10-29  10.91  11.15  10.77  11.06      11.06   684300
# 2021-11-01  11.19  11.59  11.10  11.51      11.51   956600
# 2021-11-02  11.50  11.61  11.29  11.40      11.40   746100
# 2021-11-03  12.04  14.25  11.92  13.64      13.64  4395300
# 2021-11-04  13.70  13.87  13.20  13.62      13.62   996600
# 2021-11-05  13.79  14.05  13.60  13.70      13.70  1228300
# ...

# %%
type(tcs)
# Out:
# pandas.core.frame.DataFrame

# %%
tcs['Open'].plot(label = 'TCS', figsize = (15,7))
plt.title('Stock Prices of TCS')
# Out:
# Text(0.5, 1.0, 'Stock Prices of TCS')

# %%
copy = tcs.copy()

# %%
copy.drop(columns=["High", "Low", "Close", "Adj Close", "Volume"], inplace=True)

# %%
copy
# Out:
#              Open
# Date
# 2021-10-01   9.57
# 2021-10-04   9.94
# 2021-10-05  10.09
# 2021-10-06  10.07
# 2021-10-07  10.08
# 2021-10-08  10.26
# 2021-10-11  10.15
# 2021-10-12  10.06
# 2021-10-13   9.94
# 2021-10-14   9.89
# 2021-10-15  10.03
# 2021-10-18  10.05
# 2021-10-19  10.13
# 2021-10-20  10.12
# 2021-10-21  10.50
# 2021-10-22  10.84
# 2021-10-25  10.66
# 2021-10-26  10.93
# 2021-10-27  10.38
# 2021-10-28  10.49
# 2021-10-29  10.91

# %%
copy['Open'].plot(label = 'TCS', figsize = (15,7))
plt.title('Stock Prices of TCS')
# Out:
# Text(0.5, 1.0, 'Stock Prices of TCS')
